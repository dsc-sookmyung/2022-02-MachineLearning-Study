# %% [markdown]
# [강의 정리 링크](https://sooking87.github.io/gdsc%20ml/gdsc-ml-9/)

# %% [markdown]
# # YOLOv3

# %%
# darknet repo에서 clone하기
git clone https://github.com/AlexeyAB/darknet
# Out:
#   Input In [1]
#     git clone https://github.com/AlexeyAB/darknet
#         ^
# SyntaxError: invalid syntax

# %%
# GPU와 opencv의 사용이 가능하도록 makefile을 수정하기
# %cd darknet
# !sed -i 's/OPENCV=O/OPENCV=1/' Makefile
# !sed -i 's/GPU-O/GPU=1/' Makefile
# !sed -i 's/CUDNN=O/CUDNN=1/' Makefile
# Out:
# c:\STUDY\4학기\2022-02-MachineLearning-Study\Advanced\week7\.ipynb_checkpoints\darknet
# 'sed'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'sed'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'sed'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# CUDA버전 확인
# !/user/local/cuda/bin/nvcc --version
# Out:
# ������ ��θ� ã�� �� �����ϴ�.

# %%
# make를 이용하여 darknet을 build
# !make
# Out:
# 'make'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %% [markdown]
# ### 사전학습된 YOLOv3 파라미터를 다운로드

# %%
# coco 데이터셋으로 이미 학습이 된 weight값들을 다운로드
# !wget http://pjreddie.com/media/files/yolov3.weights
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# helper 함수들
def imShow(path):
    import cv2
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    image = cv2.imread(path) # 경로로부터 이미지를 불러서 읽어온다.
    height, width = image.shape[:2]
    resized_image = cv2.resize(image, (3*width, 3*height), interpolation = cv2.INTER_CUBIC) # 영상을 3배로 키운다(크게 보여주기 위해서)
    
    fig = plt.gcf()
    fig.set_size_inches(18, 10)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.show()
    
# google colab으로 파일을 업로드할 때 사용하는 함수를 정의
def upload():
    from google.colab import files
    uploaded = files.upload()
    for name, data in uploaded.items():
        with open(name, "wb") as f:
            f.write(data)
            print("saved file", name)
            
# google colab에서 파일을 다운로드할 때 사용하는 함수를 정의
def download(path):
    from google.colab import files
    files.download(path)

# %%
# darknet detection을 실행하기
# !../darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# '..'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
imShow("../darknet/data/person.jpg")

# %%
imShow("predictions.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\STUDY\4학기\2022-02-MachineLearning-Study\Advanced\week7\.ipynb_checkpoints\[week7][손수경]강의정리_및_코드실습.ipynb 셀 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/4%ED%95%99%EA%B8%B0/2022-02-MachineLearning-Study/Advanced/week7/.ipynb_checkpoints/%5Bweek7%5D%5B%EC%86%90%EC%88%98%EA%B2%BD%5D%EA%B0%95%EC%9D%98%EC%A0%95%EB%A6%AC_%EB%B0%8F_%EC%BD%94%EB%93%9C%EC%8B%A4%EC%8A%B5.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> imShow("predictions.jpg")
#
# c:\STUDY\4학기\2022-02-MachineLearning-Study\Advanced\week7\.ipynb_checkpoints\[week7][손수경]강의정리_및_코드실습.ipynb 셀 12 in imShow(path)
#       <a href='vscode-notebook-cell:/c%3A/STUDY/4%ED%95%99%EA%B8%B0/2022-02-MachineLearning-Study/Advanced/week7/.ipynb_checkpoints/%5Bweek7%5D%5B%EC%86%90%EC%88%98%EA%B2%BD%5D%EA%B0%95%EC%9D%98%EC%A0%95%EB%A6%AC_%EB%B0%8F_%EC%BD%94%EB%93%9C%EC%8B%A4%EC%8A%B5.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> get_ipython().run_line_magic('matplotlib', 'inline')
#       <a href='vscode-notebook-cell:/c%3A/STUDY/4%ED%95%99%EA%B8%B0/2022-02-MachineLearning-Study/Advanced/week7/.ipynb_checkpoints/%5Bweek7%5D%5B%EC%86%90%EC%88%98%EA%B2%BD%5D%EA%B0%95%EC%9D%98%EC%A0%95%EB%A6%AC_%EB%B0%8F_%EC%BD%94%EB%93%9C%EC%8B%A4%EC%8A%B5.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> image = cv2.imread(path) # 경로로부터 이미지를 불러서 읽어온다.
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/4%ED%95%99%EA%B8%B0/2022-02-MachineLearning-Study/Advanced/week7/.ipynb_checkpoints/%5Bweek7%5D%5B%EC%86%90%EC%88%98%EA%B2%BD%5D%EA%B0%95%EC%9D%98%EC%A0%95%EB%A6%AC_%EB%B0%8F_%EC%BD%94%EB%93%9C%EC%8B%A4%EC%8A%B5.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> height, width = image.shape[:2]
#       <a href='vscode-notebook-cell:/c%3A/STUDY/4%ED%95%99%EA%B8%B0/2022-02-MachineLearning-Study/Advanced/week7/.ipynb_checkpoints/%5Bweek7%5D%5B%EC%86%90%EC%88%98%EA%B2%BD%5D%EA%B0%95%EC%9D%98%EC%A0%95%EB%A6%AC_%EB%B0%8F_%EC%BD%94%EB%93%9C%EC%8B%A4%EC%8A%B5.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> resized_image = cv2.resize(image, (3*width, 3*height), interpolation = cv2.INTER_CUBIC) # 영상을 3배로 키운다(크게 보여주기 위해서)
#      <a href='vscode-notebook-cell:/c%3A/STUDY/4%ED%95%99%EA%B8%B0/2022-02-MachineLearning-Study/Advanced/week7/.ipynb_checkpoints/%5Bweek7%5D%5B%EC%86%90%EC%88%98%EA%B2%BD%5D%EA%B0%95%EC%9D%98%EC%A0%95%EB%A6%AC_%EB%B0%8F_%EC%BD%94%EB%93%9C%EC%8B%A4%EC%8A%B5.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> fig = plt.gcf()
#
# AttributeError: 'NoneType' object has no attribute 'shape'
