# %% [markdown]
# ## Lec 1. Machine Learning Basic concepts
# >[ML] 기본 용어 정리
# >
#  **📖 ML의 정의**
#  - 배경) Explicit programming의 한계
#  - 프로그램 자체가 데이터를 보고 학습해서 배우는 능력을 가진 프로그램
#
# **📖 Learning 종류**
#  - 주어진 데이터로 학습하는 방법에 따라 분리
# 	  **1. Supervised learning** *>>>주로 다룰 것*
# 	  - labeled data(≒training set)를 가지고 학습하는 방식
# 	  - ML에서 대부분의 problem type에 적용
# 	  -  ex. lmage labeling, Email spam filter, Predicting exam
#
# 	**2. Unsupervised learning**
# 	 - un-labeled data를 가지고 (스스로) 학습하는 방식
# 	 - ex. Google news grouping, Word clustering
#
# **📌 Supervised learning**
# - training data set --((ML))--> model 생성
# 	- training data set = X [(Y를 결정짓는) Feature] + Y[label]로 구성
# 	- 이후 모르는 값 X_t를 넣었을 때 Y_t 자체적 도출 가능
# - Type
# 	- Regression(회귀)
# 		- 독립변수 ⇋ 종속변수 상관관계 모델링(by 수식) 하는 기법
# 		- 양적 종속변수
# 		- 실제 값과 예측 값의 차이를 최소화 하는 식을 찾는 것
# 	- Classification(분류)
# 		- 범주형 종속변수
# 		- Binary classification : 선택지를 2가지 범주로 제한해 분류
# 		- Multi-label classification : 다중 선택지 중 하나 선택해 분류
#
# ----
# ## Lec 2. Simple Linear Regression
# >[Tensorflow] 단순 선형회귀 익히기
#
# **📖 Regression(회귀)란**
# - Data값이 일정한 값(평균)으로 돌아가려는 경향  이용
# - 지도학습 분류 중 하나로 연속형 변수를 예측하는데 사용됨
#
# 	**📌 Linear Regression(선형회귀)**
# 	- 전제) data가 선형적인 감소/증가 관계에 있는 경우
# 	- Data를 가장 잘 대변하는 직선의 방정식 찾기 (= 기울기, y절편 찾기)
# 	- |실제 값 - 예측 값| 을 최소화하는 식을 찾는다.
# 	- 선형 회귀 : y = Wx + b
# 		- W : 독립 변수(x) 값에 영향을 미치는 회귀 계수 (Regression Coefficient)
#
# 	📌 **Hypothesis (가설) 중 최선책 고르기**
# 	>**가설 : H(x) = Wx + b**
# 	![](https://1.bp.blogspot.com/-Yk9jDl3QBcQ/XElthtQj7-I/AAAAAAAAA1s/eI1tG2DZH9sNYXnwU7NgOJiIDP7-OIIzACEwYBhgL/s640/%25E1%2584%2589%25E1%2585%25B3%25E1%2584%258F%25E1%2585%25B3%25E1%2584%2585%25E1%2585%25B5%25E1%2586%25AB%25E1%2584%2589%25E1%2585%25A3%25E1%2586%25BA%2B2019-01-23%2B%25E1%2584%258B%25E1%2585%25A9%25E1%2584%2592%25E1%2585%25AE%2B4.14.09.png)
# 	- data(x, y) 들을 가장 잘 대변하고 있는 직선 함수 찾기
# 	 = Cost가 가장 적다 ... Cost가 가장 적은 함수의 W, b를 어떻게 결정?
#
# 	📌**Cost (Loss)** : H(x) - y
# 		- 세운 가설, 예측값(H(x))과 실제 데이터(y)의 차이 (사실 얘는 Error)
# 		- 즉, ∑Cost 값이 작다 ≒ 해당 가설이 Data를 잘 표현하고 있다
# 		- But!! Cost가 양수, 음수로 모두 나올 수 있으므로 무턱대고 합하면 X
# 			- 따라서 Cost값을 제곱해서 고려한다.
# 		* **Cost Function**
#         - 따라서, Cost는 (H(x) - y)의 제곱의 평균
# 		![](https://mblogthumb-phinf.pstatic.net/MjAxNzA3MTZfMTQ4/MDAxNTAwMTc1OTY3MDI2.e5avgfvG675Zl5vrxSHjUbqsK9b_A7VC6lLNiIen5eQg.hi5128vp6IWBCXikBDnhIGBBHz1anEf5jv-InyMJEEsg.PNG.varkiry05/%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7_2017-07-16_%EC%98%A4%EC%A0%84_11.54.16.png?type=w800)
# 	- 따라서 이 **Cost function을 최소화**하는 것이 학습 러닝의 최종 목적

# %% [markdown]
# ## Lec 3. How to minimize cost?
#
# 📌 **Goal : Data를 통해 Cost가 최소값이 되는 W(+ b) 찾기**
#
# - Simplified Hypothesis >>  H(x) = Wx (b 생략) → Cost도 b 생략
#
# ![image.png](attachment:image.png)
#
# - data set을 이용해 cost값이 최저점이 되는 W, b값을 찾음
# - 컴퓨터는 어떻게 최저점을 찾나? → Gradient descent algorithm 이용
#     - 변수가 2개 이상일 때도 찾기 가능
#
# 📌**Gradient descent가 동작하는 방식**
#
# 1. W, b의 initial 값을 정함 : 보통 0, 0에서 시작
#
# 2. cost(W, b)값을 cost가 최소화되는 방향으로 W, b값 지속적으로 조정해나감
#     - 특정 값(W)에서 gredient 구함
#     - W - (W * Gradient)를 구해 다시 W에 저장 →이러면 cost가 최소가 되는 지점에 도달. 그때 W값 알 수 있음
#
#     ✅ **여기서 W는 길이가 아니라 X축으로 들어감! 헷갈리지 말 것. Y축은 cost임**
#
# 3. minimum에 도달했다고 판단될 때 까지 반복
#
# - Gradient는 cost(W)를 미분해서 구할 수 있음 (이때 2m으로 나눔 - 미분 시 깔끔하게 하려고)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# - W에 대해 편미분 해 Gradient 값 구함. 따라서 위 수식이 gradient descent 표현
# - 이때 α값 == Learning rate(학습률), W의 update 정도 결정
#
# 📌**Gradient descent algorithm 정리_최종_최최종..**
#
# - W(Weight)값을 지속적으로 업데이트 해나가는 알고리즘
# - 그 전 W에서 cost(w)' * α를 빼준 값을 다시 W로 갱신
# - 그럼 cost의 순간 변화율의 값이 0에 가까울 때 (= cost가 최소일 때) W의 변화 또한 거의 없을 것 => W 확정
#
# - 이때, 차원이 확장될 경우 도달한 cost 최저점이 global minimum이 아니라 local minimum일수도 있음 (수학시간에 배운 부분 최솟값인가랑 비슷한듯)
#     - Convex function : local min == global min인 경우 (local min이 2개 이상 존재X)

# %% [markdown]
# # 실습

# %%
import tensorflow as tf
import numpy as np
#tf.enable_eager_execution()
#즉시수행

# %% [markdown]
# ✅tf.reduce_mean()
# - 평균 구하는 메소드
# - reduce -> 차원(Rank)가 하나 줄어들면서 평균 구함
#
# ✅tf.square()
# - 넘겨받은 값 제곱함
#
# ✅Error == 예측값 - 실제값
#
# ✅Cost == (예측값 - 실제값)^2의 평균
#
# - Cost function을 tensorflow 코드로 정의
#     - cost = tf.reduce_mean(tf.square(hypothesis - y_data))

# %% [markdown]
# # Gradient descent (경사하강 알고리즘)
# : Cost function에서 Cost를 minimize하는 W, b를 찾는 알고리즘
#
#
# - GradientTape()
#     - 주로 with 구문과 세트로 사용됨
#     - with 구문 안 변수들의 변화 정보를 tape에 기록함
# - gradient(A, [b.c])
#     - tape의 메소드
#     - 함수(A)에 대해 변수들([b,c])에 대한 개별 미분값을 구해 tuple로 반환
# - A.assign_sub(B)
#     - A = A - B

# %%
#H(x) = Wx + b
# input, output 값이 일치하는 data값 (알맞게 나오려면 W = 1, b = 0이 나와야 함이 예측 가능하다.)
x_data = [1, 2, 3, 4, 5]
y_data = [1, 2, 3, 4, 5]

#tensorflow의 variable로 W, b 초기값 정의하기 (임의의 값)
W = tf.Variable(2.9)
b = tf.Variable(0.5)

#Gradient descent를 tensorflow로 구현하기 - 일반적으로 GradientTape를 사용해 주로 구현함

#Learning_rate initialize : 각 변수에 대해 구한 gradient 값을 얼마나 반영할지 결정(작을수록 점진적 변화)
learning_rate = 0.01

for i in range(100): #W, b 업데이트
    #Gradient descent (tape에 변수 W, b의 정보 기록)
    with tf.GradientTape() as tape:
        hypothesis = W * x_data + b
        cost = tf.reduce_mean(tf.square(hypothesis - y_data))
    #gradient - cost라는 함수에 대해 W, b의 기울기 각각 구함
    W_grade, b_grade = tape.gradient(cost, [W,b])
    #assing_sub
    W.assign_sub(learning_rate * W_grade)
    b.assign_sub(learning_rate * b_grade)
    if i % 10 == 0: #10번 단위로 W, b, const 변화 확인 
        print("{:5}|{:10.4f}|{:10.4f}|{:10.6f}".format(i, W.numpy(), b.numpy(), cost))

#이렇게 epoch 100번 이후 최종 W, b값 갱신됨 -> hypothesis 결정
# Out:
#     0|    2.4520|    0.3760| 45.660004
#    10|    1.1036|    0.0034|  0.206336
#    20|    1.0128|   -0.0209|  0.001026
#    30|    1.0065|   -0.0218|  0.000093
#    40|    1.0059|   -0.0212|  0.000083
#    50|    1.0057|   -0.0205|  0.000077
#    60|    1.0055|   -0.0198|  0.000072
#    70|    1.0053|   -0.0192|  0.000067
#    80|    1.0051|   -0.0185|  0.000063
#    90|    1.0050|   -0.0179|  0.000059

# %% [markdown]
# W
# - 주어진 초기 값 (2.9)부터 시작 ~ 점점 감소해 1.0으로 수렴
#
# b
# - 0.5에서 시작 ~ 점점 감소해 -0.0 즉, 거의 0으로 수렴
#
# cost
# - cost는 값이 작을수록 좋음!! (100번 이상 수행 시 0에 가까운 값)
# - cost가 0에 가깝다 = 모델(가설)이 실제 data와 거의 일치하게 됨 (오차 작아짐) = 실제값 예측에 good

# %%
# predict (이렇게 완성된 hypothesis를 가지고 새로운 data로 예측해보기)
# 새로운 data (x = 5, 2.5)를 넣어도 y_data가 그대로 잘 출력됨?
print(W * 5 + b)
print(W * 2.5 + b)
# Out:
# tf.Tensor(5.0066934, shape=(), dtype=float32)
# tf.Tensor(2.4946523, shape=(), dtype=float32)

# %% [markdown]
# 실제로 y_data가 5, 2.5에 가깝게 나옴!!

# %% [markdown]
# # cost minmize 구현
# : cost(W) = W(x)로 단순화된 상태
#
# ✅ np.linspace (start, end, interval)
# - start ~ end 사이를 interval만큼 나눈 값 차례로 도출

# %%
# 1. cost(W) 구현 (in python) 

import numpy as np

X = np.array([1, 2, 3])
Y = np.array([1, 2, 3])

#cost(W) 정의
def cost_func(W, X, Y):
    c = 0
    for i in range(len(X)):
        c += (W * X[i] - Y[i])**2 #c == 예측값 - 실제값의 제곱의 합 
    #최종 cost값 반환
    return c / len(X)

for feed_W in np.linspace(-3, 5, num=15):
    curr_cost = cost_func(feed_W, X, Y)
    print("{:6.3f} | {:10.5f}".format(feed_W, curr_cost))
    
#cost는 W 관련 함수이므로 W 값에 따라 변화
# Out:
# -3.000 |   74.66667
# -2.429 |   54.85714
# -1.857 |   38.09524
# -1.286 |   24.38095
# -0.714 |   13.71429
# -0.143 |    6.09524
#  0.429 |    1.52381
#  1.000 |    0.00000
#  1.571 |    1.52381
#  2.143 |    6.09524
#  2.714 |   13.71429
#  3.286 |   24.38095
#  3.857 |   38.09524
#  4.429 |   54.85714
#  5.000 |   74.66667

# %%
# 2. cost(W) 구현 (in Tensorflow)

X = np.array([1, 2, 3])
Y = np.array([1, 2, 3])

def cost_func(W, X, Y):
    hypothesis = X * W #예측값
    return tf.reduce_mean(tf.square(hypothesis - Y))

W_values = np.linspace(-3, 5, num=15)
cost_values = []

for feed_W in W_values:
    curr_cost = cost_func(feed_W, X, Y)
    cost_values.append(curr_cost)
    print("{:6.3f} | {:10.5f}".format(feed_W, curr_cost))
# Out:
# -3.000 |   74.66667
# -2.429 |   54.85714
# -1.857 |   38.09524
# -1.286 |   24.38095
# -0.714 |   13.71429
# -0.143 |    6.09524
#  0.429 |    1.52381
#  1.000 |    0.00000
#  1.571 |    1.52381
#  2.143 |    6.09524
#  2.714 |   13.71429
#  3.286 |   24.38095
#  3.857 |   38.09524
#  4.429 |   54.85714
#  5.000 |   74.66667

# %% [markdown]
# ✅ tf.Variable()
#
# - 파라미터를 변수로 만들어서 할당해 정의함
#
# ✅ tf.random_normal(모양 및 개수, start, end)
#
# - 정규 분포를 따르는 (start~end 범위 내) random number를 n개 짜리 변수로 만듦

# %%
# 3. gradient descent 구현 (in Tensorflow)

#코드 여러번 수행할 때 동일한 조건 보장 - random seed를 0으로 초기화
tf.random.set_seed(0)

x_data = [1., 2., 3., 4.]
y_data = [1., 3., 5., 7.]

#-100~100 사이 랜덤한 변수 1개 만들어서 W에 할당해 정의함
#W = tf.Variable(tf.random.normal((1,), -100., 100.))
#W = tf.Variable([5.0])
W = tf.Variable([100.0])

for step in range(300):
    hypothesis = W * X
    cost = tf.reduce_mean(tf.square(hypothesis - Y)) #cost func 구현

    #gradient descent 구현
    alpha = 0.01 #learning_rate
    gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X) - Y, X))# Cost(W)' (기울기)
    descent = W - tf.multiply(alpha, gradient)
    #W에 계산한 값 할당 (+=)
    W.assign(descent)
    
    #10번마다 cost, W 값 중간 출력
    if step % 10 == 0:
        print('{:5} | {:10.4f} | {:10.6f}'.format(step, cost.numpy(), W.numpy()[0]))
# Out:
#     0 | 45738.0000 |  95.379997
#    10 | 17586.2363 |  59.523170
#    20 |  6761.8979 |  37.289059
#    30 |  2599.9453 |  23.502121
#    40 |   999.6769 |  14.953116
#    50 |   384.3751 |   9.652050
#    60 |   147.7920 |   6.364964
#    70 |    56.8259 |   4.326708
#    80 |    21.8495 |   3.062825
#    90 |     8.4011 |   2.279117
#   100 |     3.2302 |   1.793155
#   110 |     1.2420 |   1.491820
#   120 |     0.4776 |   1.304968
#   130 |     0.1836 |   1.189104
#   140 |     0.0706 |   1.117260
#   150 |     0.0271 |   1.072711
#   160 |     0.0104 |   1.045086
#   170 |     0.0040 |   1.027957
#   180 |     0.0015 |   1.017336
#   190 |     0.0006 |   1.010749
#   200 |     0.0002 |   1.006665
#   210 |     0.0001 |   1.004133
#   220 |     0.0000 |   1.002563
#   230 |     0.0000 |   1.001589
#   240 |     0.0000 |   1.000986
#   250 |     0.0000 |   1.000611
#   260 |     0.0000 |   1.000379
#   270 |     0.0000 |   1.000235
#   280 |     0.0000 |   1.000146
# ...

# %% [markdown]
# cost값 -> 0으로 수렴
#
# W값 -> 1로 수렴 확인 가능
#
# **W에 처음에 어떤 값을 넣더라도 같은 결과가 나옴**
